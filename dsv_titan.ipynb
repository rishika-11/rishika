# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika-11/rishika/blob/main/dsv_titan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### load data set
import pandas as pd
import numpy as np

df=pd.read_csv('/content/TITAN.csv')
print (df)

# %%
####display first 10 numbers
df.head(10)
# Out:
#          Date Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  2000-01-03  TITAN     EQ  ...     NaN                 NaN          NaN
# 1  2000-01-04  TITAN     EQ  ...     NaN                 NaN          NaN
# 2  2000-01-05  TITAN     EQ  ...     NaN                 NaN          NaN
# 3  2000-01-06  TITAN     EQ  ...     NaN                 NaN          NaN
# 4  2000-01-07  TITAN     EQ  ...     NaN                 NaN          NaN
# 5  2000-01-10  TITAN     EQ  ...     NaN                 NaN          NaN
# 6  2000-01-11  TITAN     EQ  ...     NaN                 NaN          NaN
# 7  2000-01-12  TITAN     EQ  ...     NaN                 NaN          NaN
# 8  2000-01-13  TITAN     EQ  ...     NaN                 NaN          NaN
# 9  2000-01-14  TITAN     EQ  ...     NaN                 NaN          NaN
#
# [10 rows x 15 columns]

# %%
###display last 6 records
df.tail(6)
# Out:
#             Date Symbol Series  ...    Trades  Deliverable Volume  %Deliverble
# 5300  2021-04-23  TITAN     EQ  ...   67099.0            406180.0       0.2353
# 5301  2021-04-26  TITAN     EQ  ...   39416.0            228386.0       0.2238
# 5302  2021-04-27  TITAN     EQ  ...   42363.0            298862.0       0.2608
# 5303  2021-04-28  TITAN     EQ  ...   37985.0            212098.0       0.2044
# 5304  2021-04-29  TITAN     EQ  ...   63568.0            492144.0       0.2553
# 5305  2021-04-30  TITAN     EQ  ...  111986.0            699586.0       0.1895
#
# [6 rows x 15 columns]

# %%
###shape
df.shape
# Out:
# (5306, 15)

# %%
##size
df.size
# Out:
# 79590

# %%
#######display column names
df.keys()
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
#######datatypes
df.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
#######no of missing values
df.isnull()
# Out:
#        Date  Symbol  Series  ...  Trades  Deliverable Volume  %Deliverble
# 0     False   False   False  ...    True                True         True
# 1     False   False   False  ...    True                True         True
# 2     False   False   False  ...    True                True         True
# 3     False   False   False  ...    True                True         True
# 4     False   False   False  ...    True                True         True
# ...     ...     ...     ...  ...     ...                 ...          ...
# 5301  False   False   False  ...   False               False        False
# 5302  False   False   False  ...   False               False        False
# 5303  False   False   False  ...   False               False        False
# 5304  False   False   False  ...   False               False        False
# 5305  False   False   False  ...   False               False        False
#
# [5306 rows x 15 columns]

# %%
####8.describe
df.describe()
# Out:
#         Prev Close         Open  ...  Deliverable Volume  %Deliverble
# count  5306.000000  5306.000000  ...        4.792000e+03  4792.000000
# mean    709.230692   709.989926  ...        4.408763e+05     0.367944
# std     785.170900   785.435092  ...        7.022005e+05     0.164969
# min      27.500000    27.000000  ...        3.600000e+02     0.023600
# 25%     192.262500   192.625000  ...        4.992600e+04     0.249000
# 50%     396.150000   398.250000  ...        2.012115e+05     0.352400
# 75%    1017.725000  1018.925000  ...        6.247118e+05     0.472900
# max    4714.600000  4730.000000  ...        2.169911e+07     1.000000
#
# [8 rows x 12 columns]

# %%
######duplicates
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5301    False
# 5302    False
# 5303    False
# 5304    False
# 5305    False
# Length: 5306, dtype: bool

# %%
######drop duplicates
df.drop_duplicates()
# Out:
#             Date Symbol Series  ...    Trades  Deliverable Volume  %Deliverble
# 0     2000-01-03  TITAN     EQ  ...       NaN                 NaN          NaN
# 1     2000-01-04  TITAN     EQ  ...       NaN                 NaN          NaN
# 2     2000-01-05  TITAN     EQ  ...       NaN                 NaN          NaN
# 3     2000-01-06  TITAN     EQ  ...       NaN                 NaN          NaN
# 4     2000-01-07  TITAN     EQ  ...       NaN                 NaN          NaN
# ...          ...    ...    ...  ...       ...                 ...          ...
# 5301  2021-04-26  TITAN     EQ  ...   39416.0            228386.0       0.2238
# 5302  2021-04-27  TITAN     EQ  ...   42363.0            298862.0       0.2608
# 5303  2021-04-28  TITAN     EQ  ...   37985.0            212098.0       0.2044
# 5304  2021-04-29  TITAN     EQ  ...   63568.0            492144.0       0.2553
# 5305  2021-04-30  TITAN     EQ  ...  111986.0            699586.0       0.1895
#
# ...

# %%
######mean
a=df.mean()
print(a)
# Out:
# Prev Close            7.092307e+02
# Open                  7.099899e+02
# High                  7.233128e+02
# Low                   6.964308e+02
# Last                  7.094491e+02
# Close                 7.094845e+02
# VWAP                  7.104154e+02
# Volume                1.172596e+06
# Turnover              7.796053e+13
# Trades                4.724186e+04
# Deliverable Volume    4.408763e+05
# %Deliverble           3.679444e-01
# dtype: float64

# %%
###median
b=df.median()
print(b)
# Out:
# Prev Close            3.961500e+02
# Open                  3.982500e+02
# High                  4.045250e+02
# Low                   3.911250e+02
# Last                  3.970250e+02
# Close                 3.963500e+02
# VWAP                  3.980950e+02
# Volume                5.491360e+05
# Turnover              2.785515e+13
# Trades                3.507650e+04
# Deliverable Volume    2.012115e+05
# %Deliverble           3.524000e-01
# dtype: float64

# %%
##### mode
df.mode()
# Out:
#             Date Symbol Series  ...   Trades  Deliverable Volume  %Deliverble
# 0     2000-01-03  TITAN     EQ  ...   7348.0              7308.0       0.3105
# 1     2000-01-04    NaN    NaN  ...   7722.0              7789.0          NaN
# 2     2000-01-05    NaN    NaN  ...   8237.0              8878.0          NaN
# 3     2000-01-06    NaN    NaN  ...   8903.0             14272.0          NaN
# 4     2000-01-07    NaN    NaN  ...  10626.0             28883.0          NaN
# ...          ...    ...    ...  ...      ...                 ...          ...
# 5301  2021-04-26    NaN    NaN  ...      NaN                 NaN          NaN
# 5302  2021-04-27    NaN    NaN  ...      NaN                 NaN          NaN
# 5303  2021-04-28    NaN    NaN  ...      NaN                 NaN          NaN
# 5304  2021-04-29    NaN    NaN  ...      NaN                 NaN          NaN
# 5305  2021-04-30    NaN    NaN  ...      NaN                 NaN          NaN
#
# [5306 rows x 15 columns]

# %%
##variance
np.var(df)
# Out:
# Prev Close            6.163772e+05
# Open                  6.167920e+05
# High                  6.384172e+05
# Low                   5.961556e+05
# Last                  6.161018e+05
# Close                 6.164325e+05
# VWAP                  6.180986e+05
# Volume                3.110610e+12
# Turnover              1.900019e+28
# Trades                1.876849e+09
# Deliverable Volume    4.929827e+11
# %Deliverble           2.720917e-02
# dtype: float64

# %%
### standard deviation
c=np.std(df)
print(c)
# Out:
# Prev Close            7.850969e+02
# Open                  7.853611e+02
# High                  7.990101e+02
# Low                   7.721111e+02
# Last                  7.849215e+02
# Close                 7.851321e+02
# VWAP                  7.861925e+02
# Volume                1.763692e+06
# Turnover              1.378412e+14
# Trades                4.332262e+04
# Deliverable Volume    7.021272e+05
# %Deliverble           1.649520e-01
# dtype: float64

# %%
df.max()
# Out:
# Date                   2021-04-30
# Symbol                      TITAN
# Series                         EQ
# Prev Close                 4714.6
# Open                         4730
# High                      4754.95
# Low                        4559.9
# Last                         4734
# Close                      4714.6
# VWAP                      4647.54
# Volume                   33276611
# Turnover              2.45134e+15
# Trades                     536406
# Deliverable Volume    2.16991e+07
# %Deliverble                     1
# dtype: object

# %%
df.min()
# Out:
# Date                  2000-01-03
# Symbol                     TITAN
# Series                        EQ
# Prev Close                  27.5
# Open                          27
# High                        28.8
# Low                           27
# Last                       27.75
# Close                       27.5
# VWAP                       27.88
# Volume                       200
# Turnover               8.125e+08
# Trades                       993
# Deliverable Volume           360
# %Deliverble               0.0236
# dtype: object

# %%
###range
df['Open'].max() - df['Open'].min()
# Out:
# 4703.0

# %%
####IQR
data['Open'].quantile([.25,.5,.75])
# Out:
# 0.25     192.625
# 0.50     398.250
# 0.75    1018.925
# Name: Open, dtype: float64

# %%
#####boxplot
import  matplotlib.pyplot
df.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
######histogram
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faaa82e32d0>,
# ...
#       dtype=object)

# %%
#####skewness
df.skew()
# Out:
# Prev Close            2.269237
# Open                  2.268736
# High                  2.263434
# Low                   2.273513
# Last                  2.266928
# Close                 2.268218
# VWAP                  2.267454
# Volume                5.081300
# Turnover              4.891056
# Trades                3.034686
# Deliverable Volume    9.581433
# %Deliverble           0.480147
# dtype: float64

# %%
####kurtosois
df.kurtosis()
# Out:
# Prev Close              6.121581
# Open                    6.130397
# High                    6.101268
# Low                     6.133979
# Last                    6.110089
# Close                   6.117145
# VWAP                    6.104379
# Volume                 54.142543
# Turnover               45.635142
# Trades                 18.182870
# Deliverable Volume    220.034892
# %Deliverble             0.003015
# dtype: float64

# %%
######scatterplot
df.plot.scatter('High','Low')

# %%
####pairplot
import seaborn as sns
sns.pairplot(df[['Open','High','Low','Last']])

# %%
####highest data
max_price = df["Close"].max() 
print(max_price)
# Out:
# 4714.6

# %%
###### lowest data
min_price = df['Close'].min()
print(min_price)
# Out:
# 27.5

# %%
#######highest open price data
max_price = df['Open'].max() 
print(max_price)
# Out:
# 4730.0
